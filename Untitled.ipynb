# %%
from qiskit import QuantumCircuit, execute, Aer
from qiskit.visualization import plot_histogram, plot_bloch_vector
from math import sqrt, pi
from qiskit.extensions import Initialize 
from qiskit.quantum_info import Operator

# %%
def nacrtaj_x(qcX):
    qcX = QuantumCircuit(1)
    qcX.x(0)
    return qcX
nacrtaj_x(qcX)
qcX.draw('mpl')

# %%
def izmjeri_x(qcX):
    backend = Aer.get_backend('statevector_simulator')
    final_state = execute(qcX,backend).result().get_statevector()
    print(final_state)
izmjeri_x(qcX)
# Out:
# [0.+0.j 1.+0.j]

# %%
backend = Aer.get_backend('unitary_simulator')
job = execute(qcX, backend)
result = job.result()
a = result.get_unitary(qcX, decimals=3)
print(a)
# Out:
# [[0.+0.j 1.+0.j]
#  [1.+0.j 0.+0.j]]

# %%
Operator(qcX)
# Out:
# Operator([[0.+0.j, 1.+0.j],
#           [1.+0.j, 0.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %%
def nacrtaj_HZH(qcHZH):
    qcHZH = QuantumCircuit(1)
    qcHZH.h(0)
    qcHZH.z(0)
    qcHZH.h(0)
    return qcHZH
nacrtaj_HZH(qcHZH)
qcHZH.draw('mpl')

# %%
def izmjeri_HZH(qcHZH):
    backend = Aer.get_backend('statevector_simulator')
    final_state = execute(qcHZH,backend).result().get_statevector()
    print(final_state)
izmjeri_HZH(qcHZH)
# Out:
# [0.+6.123234e-17j 1.-6.123234e-17j]

# %%
Operator(qcHZH)
# Out:
# Operator([[0.+0.j, 1.+0.j],
#           [1.+0.j, 0.+0.j]],
#          input_dims=(2,), output_dims=(2,))

# %%
def nacrtaj_HCH(qcHCH):
    qcHCH = QuantumCircuit(2,1)
    qcHCH.h(0)
    qcHCH.h(1)
    qcHCH.cx(0,1)
    qcHCH.h(0)
    qcHCH.h(1)
    return qcHCH
nacrtaj_HCH(qcHCH)
qcHCH.draw('mpl')

# %%
mpnum.mparray.localouter(a, b)
# Out:
# [[ 1.-0.j  0.+0.j -0.+0.j  0.+0.j]
#  [ 0.+0.j  1.-0.j  0.+0.j -0.+0.j]
#  [ 0.+0.j -0.+0.j  0.+0.j  1.-0.j]
#  [-0.+0.j  0.+0.j  1.-0.j  0.+0.j]]

# %%
Operator(qcHCH)
# Out:
# Operator([[1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j],
#           [0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j]],
#          input_dims=(2, 2), output_dims=(2, 2))

# %%
def nacrtaj_C(qcC):
    qcC = QuantumCircuit(2,1)
    qcC.cx(1,0)
    return qcC
nacrtaj_C(qcC)
qcC.draw('mpl')

# %%
Operator(qcC)
# Out:
# Operator([[1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j],
#           [0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j]],
#          input_dims=(2, 2), output_dims=(2, 2))

# %%
qcC.draw('mpl')

# %%
# Out:
# Operator([[1.+0.j, 0.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 1.+0.j, 0.+0.j, 0.+0.j],
#           [0.+0.j, 0.+0.j, 0.+0.j, 1.+0.j],
#           [0.+0.j, 0.+0.j, 1.+0.j, 0.+0.j]],
#          input_dims=(2, 2), output_dims=(2, 2))

# %%
from qiskit.visualization import plot_bloch_multivector
# %matplotlib inline
backend = Aer.get_backend('statevector_simulator')
out = execute(qcHCH,backend).result().get_statevector()
plot_bloch_multivector(out)

# %%
backend = Aer.get_backend('statevector_simulator')
out = execute(qcC,backend).result().get_statevector()
plot_bloch_multivector(out)

# %%
backend = Aer.get_backend('statevector_simulator')
out = execute(qcHZH,backend).result().get_statevector()
plot_bloch_multivector(out)

# %%
backend = Aer.get_backend('statevector_simulator')
out = execute(qcX,backend).result().get_statevector()
plot_bloch_multivector(out)
